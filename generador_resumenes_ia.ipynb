# %%
# Texto de ejemplo para probar el sistema

texto = """
La inteligencia artificial está transformando múltiples sectores,
incluyendo educación, salud, finanzas y negocios. Su capacidad
para analizar grandes cantidades de datos permite automatizar
procesos y mejorar la toma de decisiones.
"""

print(texto)
# Out:
# La inteligencia artificial está transformando múltiples sectores,
# incluyendo educación, salud, finanzas y negocios. Su capacidad
# para analizar grandes cantidades de datos permite automatizar
# procesos y mejorar la toma de decisiones.

# %%
# Instalar librería de resumen

# !pip install sumy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 28.8 MB/s eta 0:00:00
# ...
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21695 sha256=f963dfb035e247f5be7209c180f5dd5e2efac11f5287843a197b9084328262bc
#   Stored in directory: /root/.cache/pip/wheels/32/99/64/59305409cacd03aa03e7bddf31a9db34b1fa7033bd41972662
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=73a3e45ab76e881f58f1c2633655e3fc76f5b0ea5f7febc3969d4fe483289c74
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built breadability docopt
# ...

# %%
# !pip install sumy nltk

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
texto = input("Pega aquí tu texto: ")
# Out:
# Pega aquí tu texto: La inteligencia artificial está revolucionando la manera en que las empresas trabajan. Actualmente se utiliza para automatizar procesos, analizar grandes cantidades de datos y mejorar la experiencia de los clientes. Muchas organizaciones implementan sistemas inteligentes para aumentar la productividad y optimizar la toma de decisiones.

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

# Procesar texto
parser = PlaintextParser.from_string(texto, Tokenizer("spanish"))

# Crear resumidor
summarizer = LsaSummarizer()

# Generar resumen (2 frases)
resumen = summarizer(parser.document, sentences_count=2)

print("\nResumen generado:\n")

for frase in resumen:
    print("-", frase)
# Out:
# Resumen generado:
#
# - Actualmente se utiliza para automatizar procesos, analizar grandes cantidades de datos y mejorar la experiencia de los clientes.
# - Muchas organizaciones implementan sistemas inteligentes para aumentar la productividad y optimizar la toma de decisiones.

# %%
print("\n" + "="*50)
print("TEXTO ORIGINAL")
print("="*50)

print(texto)

print("\n" + "="*50)
print("RESUMEN GENERADO")
print("="*50)

for frase in resumen:
    print("-", frase)
# Out:
# ...
# TEXTO ORIGINAL
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_18527/3688800979.py in <cell line: 0>()
#       3 print("="*50)
#       4
# ----> 5 print(texto)
#       6
#       7 print("\n" + "="*50)
#
# NameError: name 'texto' is not defined
